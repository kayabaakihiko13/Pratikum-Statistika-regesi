# %% [markdown]
# <div id="">
#     <h2 align="center">Pratek Statiska Regesi</h2>
#     <p></p>
# </div>

# %% [markdown]
# <div>
#     <h1>Bab 1 Pengenalkan Python</h1>
#     <p>bab ini mengenalkan bahasa python dasar dan apa hubungannya dengan statiska
#     <center><img style="center" src="https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg"/></center>
#     <p>python merupakan bahasa pemprograman terfavorit di tahun 2021 dan kedua pada tahun 2022.
#     <br>pada laporan pembuatan kita perlu adanya modul yang bisa membantu para mahasiswa untuk memahami pada modul statiska</p>
#     <h3>Let Goo</h3>
# </div>

# %% [markdown]
# <div>
#     <h2>Soal Bab 1</h2>
#     <ol>
#     <li><h4>Mengapa python berkaitan dengan metode statistika?</h4><hr>
#     <p1>Python ini bahasa pemprograman yang bersifat open source alias gratis tidak seperti bahasa pemprograman,selain bahasa pemprograman tidak sesuah bahasa lainnya kalau orang statiska bahasa R kalau CS (Computer Science) tidak sesusah bahasa Java,C,C++ dsb.<br>libary pada python untuk mendukung statiska juga banyak,seperti numpy,pandas,scipy,sklearn,statmodels.</p1></li><br>
#     <li>
#     <h4>
#         apakah ada cara lain untuk menggunakan bahasa pemprogramn Python selain menginstall di desktop computer?<br>jika ada sebutkan dan bagaimana cara menggunakannya?<hr>
#     <p>Jelas Ada dong,menurut pribadi sih saya kadang <a href="https://colab.research.google.com/">Colab</a> dan saya juga pakai <a href="https://www.programiz.com/python-programming/online-compiler/">Programiz.</a><br>
#     kalau colab untuk menjalankan hal2 yang berat,seperti Model Machine Learning maupun model Deep learning<br>kalau untuk programiz ketika males buka pas ada kuis-kuis tentang Data stuktur logika di Linkend.
#     </p>
#     </h4>
#     </li>
#     <li>
#     <h4>
#         Sebutkan dan jelaskan library Python yang dapat digunakan untuk menganalisis data dan mengvisualisasikan data
#     </h4><hr>
#     <h5>Kalau untuk melakukan manipulasi data</h5>
#     <ul>
#         <li><a href="https://numpy.org/">Numpy</a></li>
#         <li><a href="https://pandas.pydata.org/">Pandas</a></li>
#     </ul><br>
#     <h5> Untuk Melakukan visualisasi data</h5>
#     <ul>
#         <li><a href="https://matplotlib.org/">Matplotlib</a></li>
#         <li><a href="https://bokeh.org/">Bokeh</a></li>
#         <li><a href="https://seaborn.pydata.org/">Seaborn(My Favorite)</a></li>
#         <li><a href="https://plotly.com/python/">Plotly</a>(My Favorite)</li>
#     </ul>
#     <h5>Untuk Melakukan model matematikan dan Statiska</h5>
#     <ul>
#         <li><a href="https://scipy.org/">Scipy</a></li>
#         <li><a href="https://www.statsmodels.org/">Statmodels</a></li>
#         <li><a href="https://scikit-learn.org">Sklearn</a></li>
#     </ul>
#     </li>
#     </ol>
# </div>

# %% [markdown]
# <div>
#     <h1 align="center">Bab 2 Metode Korelasi </h1>
#     <p align="justify">Analisis Korelasi Merupakan salah satu metode statiska yang mengelidiki hubungan dua variabel.Metode ini digunakan untuk mengetahui seberapa kuat atau lemahnya hubungan antar dua variabel.<br>contoh pengaplikasinya metode korelasi misalnya adalah kita mengetahui apakah varaibel ini memiliki hubungan kuat apa lemah (besti/tidak)</p>
# </div>

# %%
import pandas as pd
score_course=[90,80,85,65,70,65,95,82,83,75]
ipk=[3.85,3.72,3.82,3.2,3.4,3.1,3.9,3.75,3.76,3.49]
data=pd.DataFrame({
    "score":score_course,
    "ipk":ipk,
})
data.head()
# Out:
#    score   ipk
# 0     90  3.85
# 1     80  3.72
# 2     85  3.82
# 3     65  3.20
# 4     70  3.40

# %% [markdown]
# <div>
#     <h2 align="center">Pearsonr Method</h2>
# </div>

# %%
from scipy.stats import pearsonr
corr,p_value=pearsonr(data.score,data.ipk)
print('nilai coorelation is:{:.3f}'.format(corr))
print('nilai p-value:{}'.format(p_value))
# Out:
# nilai coorelation is:0.960
# nilai p-value:1.0241823785354165e-05

# %% [markdown]
# <h3 align="center">Spearmanr Method</h3>

# %%
from scipy.stats import spearmanr
corr,p_value=spearmanr(data.score,data.ipk)
print('nilai coorelation is:{:.3f}'.format(corr))
print('nilai p-value:{}'.format(p_value))
# Out:
# nilai coorelation is:0.997
# nilai p-value:3.698093220209985e-10

# %% [markdown]
# <h3 align="center">korelasi Tau Kendali</h3>

# %%
from scipy.stats import kendalltau
corr,_=kendalltau(data.score,data.ipk)
print('nilai coorelation is:{:.3f}'.format(corr))
# Out:
# nilai coorelation is:0.989

# %% [markdown]
# <div>
#     <h4 align="center">Soal Korelasi</h4>
# </div>

# %%
# masukan read data csv
data_ibt=pd.read_csv('Data Nilai Bahasa Inggris.csv')
data_ibt=data_ibt.drop(columns=['Data ke-'],axis=1)
data_ibt.columns=data_ibt.columns.str.lower()
data_ibt.columns=data_ibt.columns.str.replace(' ','_')
data_ibt.head()
# Out:
#    nilai_toefl_ibt  nilai_akhir_kelas
# 0              118                 90
# 1              107                 74
# 2              104                 71
# 3              110                 77
# 4              103                 71

# %%
corr,_=pearsonr(data_ibt.nilai_toefl_ibt,data_ibt.nilai_akhir_kelas)
print('Pearsonr Method'.center(50,'='))
print('nilai Correlation:{:.3f}'.format(corr))
print('Spearmanr Method'.center(50,'='))
corr,_=spearmanr(data_ibt.nilai_toefl_ibt,data_ibt.nilai_akhir_kelas)
print('nilai Correlation:{:.3f}'.format(corr))
print('Kendalltau Method'.center(50,'='))
corr,_=kendalltau(data_ibt.nilai_toefl_ibt,data_ibt.nilai_akhir_kelas)
print('nilai kendalltau:{:.3f}'.format(corr))
# Out:
# =================Pearsonr Method==================
# nilai Correlation:0.969
# =================Spearmanr Method=================
# nilai Correlation:0.983
# ================Kendalltau Method=================
# nilai kendalltau:0.940

# %% [markdown]
# Kesimpulan:
# pada data tersebut bahwa yang memiliki korelasi kuat pada metode spearmanr

# %% [markdown]
# <div>
#     <h1 align="center">Bab 3 Regesi Linear Sederhana </h1>
#     <p >Analisis Regresi pada dasarnya merupakan serangkaian proses metode statiska yang menyelediki
#     hubungan antara variabel dependen(terikat) dan variabel independent(bebas)<br>
#     Teknik ini banyak digunakan hampir semua bidang seperti teknik,ilmu fisika,kimia,ekonomi,manajement,ilmu kehidupan dan biologi,ilmu sosial dsb</p>
# </div>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
# %matplotlib inline

# %% [markdown]
# <div>
#     <h3>Teori Regesi Linear Sederhana</h3>
# </div>

# %%
score_course=[90,80,85,65,70,65,95,82,83,75]
ipk=[3.85,3.72,3.82,3.2,3.4,3.1,3.9,3.75,3.76,3.49]
data=pd.DataFrame({
    "score":score_course,
    "ipk":ipk,
})
data.head()
# Out:
#    score   ipk
# 0     90  3.85
# 1     80  3.72
# 2     85  3.82
# 3     65  3.20
# 4     70  3.40

# %%
sns.regplot(x=data.score,y=data.ipk,data=data,line_kws={'color':'red'})
# Out:
# <AxesSubplot: xlabel='score', ylabel='ipk'>

# %% [markdown]
# ini regession sebelum di olah

# %% [markdown]
# <div>
#     <h3>Studi Kasus</h3>
# </div>

# %%
# studi kasus
df=pd.read_csv('Data_Pendapatan.csv')
df=df.drop(columns=['Data ke-'],axis=1)
df.columns=df.columns.str.lower()
df.head()
# Out:
#    bekerja_tahun  pendapatan_juta
# 0            1.1          3934300
# 1            1.3          4620500
# 2            1.5          3773100
# 3            2.0          4352500
# 4            2.2          3989100

# %%
# bagaimana hunbungan dengan variabel bekerja_tahun dan pendapatan_juta
from statsmodels.api import qqplot
feature=df.bekerja_tahun
target=df.pendapatan_juta
fig,ax=plt.subplots(1,2,figsize=(20,10))
sns.scatterplot(x=feature,y=target,ax=ax[0])
ax[0].set_title('Coorlelation of bekerja_tahun and pendapatan_juta')
qqplot(target,line='s',ax=ax[1])
ax[1].set_title('Q-Q plot for pendapatan_juta')
plt.show()

# %%
# pensebarannya sebelum modeling
sns.distplot(df.pendapatan_juta)
# Out:
# /tmp/ipykernel_9474/3107954911.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.pendapatan_juta)
# <AxesSubplot: xlabel='pendapatan_juta', ylabel='Density'>

# %%
# hubungan regesi sebelum di modeling
sns.regplot(x='bekerja_tahun',y='pendapatan_juta',data=df)
# ini masih berjauhan nah bagaimana untuk mengubah nya
# Out:
# <AxesSubplot: xlabel='bekerja_tahun', ylabel='pendapatan_juta'>

# %% [markdown]
# Menbangun regesi

# %%
# kita pakai pakage statsmodels
import statsmodels.api as sm
target_penjualan=df.pendapatan_juta
feature=df.bekerja_tahun
feature=sm.add_constant(feature)
modeling=sm.OLS(target_penjualan,feature).fit()# kita masukan (dependen,independen)
print(modeling.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        pendapatan_juta   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Sun, 27 Nov 2022   Prob (F-statistic):           1.14e-20
# Time:                        19:28:42   Log-Likelihood:                -439.60
# No. Observations:                  30   AIC:                             883.2
# Df Residuals:                      28   BIC:                             886.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2.579e+06   2.27e+05     11.347      0.000    2.11e+06    3.04e+06
# ...

# %% [markdown]
# jadi B0 bernilai 2.579.000 dan untuk tahun b1=945.000
# kesimpulannya bahwa setiap penganlaman kenaikan satu tahun akan bertambah pendapatan senilai 945.000

# %%
# nah kita uji t_value dan p_value
plt.title('Pesebaran data setelah OLS')
sns.distplot(modeling.resid)
# Out:
# /tmp/ipykernel_9474/1009123200.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(modeling.resid)
# <AxesSubplot: title={'center': 'Pesebaran data setelah OLS'}, ylabel='Density'>

# %% [markdown]
# <div>
#     <h4 align="center">cara melihat hasil prediksi dan residual</h4>
# </div>

# %%
nilai_prediksi=modeling.predict(feature)
print(nilai_prediksi.head())
# Out:
# 0    3.618716e+06
# 1    3.807715e+06
# 2    3.996714e+06
# 3    4.469212e+06
# 4    4.658212e+06
# dtype: float64

# %%
nilai_resedu=modeling.resid
print(nilai_resedu.head())
# Out:
# 0    315584.124773
# 1    812784.878344
# 2   -223614.368085
# 3   -116712.484158
# 4   -669111.730587
# dtype: float64

# %% [markdown]
# <div>
#     <h3 align="center">Soal Regesi Linear Sederhana</h3>
# </div>

# %%
data_iklan=pd.read_csv('Data Produk Minuman.csv')
data_iklan=data_iklan.drop(columns=['Data ke-'],axis=1)
data_iklan=data_iklan.rename(columns={"Biaya iklan ($ thousand)":"biaya_iklan","Jumlah Produk terjual (million)":"produk_terjual"})
data_iklan.columns
# Out:
# Index(['biaya_iklan', 'produk_terjual'], dtype='object')

# %%
# tampilkan data awalnya
data_iklan.head()
# Out:
#    biaya_iklan  produk_terjual
# 0          587             564
# 1          781             571
# 2          937             583
# 3          988             593
# 4          441             531

# %% [markdown]
# <h4>Mencari hubungan sebelum OLS</h4>

# %%
plt.title("Hubungan biaya_iklan dan produk_terjual pra-OLS")
sns.regplot(x='biaya_iklan',y='produk_terjual',data=data_iklan,line_kws={'color':'red'})
# Out:
# <AxesSubplot: title={'center': 'Hubungan biaya_iklan dan produk_terjual pra-OLS'}, xlabel='biaya_iklan', ylabel='produk_terjual'>

# %% [markdown]
# ## check pesebaran data

# %%
sns.distplot(data_iklan)
# Out:
# /tmp/ipykernel_9474/3130856702.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_iklan)
# <AxesSubplot: ylabel='Density'>

# %%
# saat nya kita mengOLS

target=data_iklan.produk_terjual
feature=data_iklan.biaya_iklan
feature=sm.add_constant(feature)
modeling_iklan=sm.OLS(target,feature).fit()
print(modeling_iklan.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         produk_terjual   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     455.0
# Date:                Sun, 27 Nov 2022   Prob (F-statistic):           7.08e-21
# Time:                        19:28:44   Log-Likelihood:                -113.51
# No. Observations:                  35   AIC:                             231.0
# Df Residuals:                      33   BIC:                             234.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         479.7566      3.351    143.172      0.000     472.939     486.574
# ...

# %%
sns.distplot(modeling_iklan.resid)
# Out:
# /tmp/ipykernel_9474/1605754515.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(modeling_iklan.resid)
# <AxesSubplot: ylabel='Density'>

# %%
from scipy.stats import shapiro
_,p_value=shapiro(modeling_iklan.resid)
if p_value>.05:
    print('Nilai H0 Tolak')
    print('Model Bagus')
else:
    print('Nilai Gagal H0 Tolak')
    print('Model Kurang Bagus')
print(p_value)
# Out:
# Nilai H0 Tolak
# Model Bagus
# 0.4970998466014862

# %% [markdown]
# <div>
#     <h1 align="center">Bab 4 Asumsi Residual</h1>
#     <p>
#     Dalam Analisis Regesi (regesi tunggal maupun banyak) terdapat asumsi utama yang harus terpenuhi antara lain:
#     </p>
#     <ol>
#         <li type="a">Adanya hubungan linear antara variabel depend y dan variabel independen x atau mendekati</li>
#         <li type="a">Error e memnpunyai mean o (null)</li>
#         <li type="a">Error e mempunyai varians standard deviasi yang konstan</li>
#         <li type="a">Error e tidak saling berkolerasi</li>
#         <li type="a">Error e berdistribusi normal</li>
#     </ol>
# </div>

# %% [markdown]
# <div>
#     <h4>Kita menggunakan menggunakan sample iklan yang sama</h4>
# </div>

# %% [markdown]
# <div>
#     <h4 align="center"> Soal Kuis</h4>
# </div>

# %%
table_enam=pd.read_csv('Data Produk Minuman.csv')
table_enam=table_enam.rename(columns={'Biaya iklan ($ thousand)':"biaya_iklan","Jumlah Produk terjual (million)":"produk_terjual"})
table_enam=table_enam.drop(columns=['Data ke-'],axis=1)
table_enam.head()
# Out:
#    biaya_iklan  produk_terjual
# 0          587             564
# 1          781             571
# 2          937             583
# 3          988             593
# 4          441             531

# %%
qqplot(table_enam.produk_terjual,line='s')
plt.title('Visualization Depeden Before OLS')
plt.show()

# %%
sns.distplot(table_enam.produk_terjual)
# Out:
# /tmp/ipykernel_9474/722839252.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(table_enam.produk_terjual)
# <AxesSubplot: xlabel='produk_terjual', ylabel='Density'>

# %%
feature=table_enam.biaya_iklan
target=table_enam.produk_terjual
feature=sm.add_constant(feature)
model_data_iklan=sm.OLS(target,feature,missing='drop').fit()
print(model_data_iklan.summary()
)
# print(feature)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         produk_terjual   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     455.0
# Date:                Sun, 27 Nov 2022   Prob (F-statistic):           7.08e-21
# Time:                        19:28:45   Log-Likelihood:                -113.51
# No. Observations:                  35   AIC:                             231.0
# Df Residuals:                      33   BIC:                             234.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         479.7566      3.351    143.172      0.000     472.939     486.574
# ...

# %% [markdown]
# <h4>Check Penyebaran Data</h4>

# %%
sns.distplot(model_data_iklan.resid)
# Out:
# /tmp/ipykernel_9474/3505579275.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(model_data_iklan.resid)
# <AxesSubplot: ylabel='Density'>

# %%
qqplot(model_data_iklan.resid,line='s')
plt.show()

# %%
t_value,p_value=shapiro(model_data_iklan.resid)
if p_value > .05:
    print('Tolak H0')
    print(p_value)
else:
    print('Gagal Tolak H0')

# print(p_value)
# Out:
# Tolak H0
# 0.4970998466014862

# %%
# check autokorelasi
sm.stats.stattools.durbin_watson(model_data_iklan.resid)
# Out:
# 1.4684302824383628

# %%
asm_homosk=plt.scatter(target,model_data_iklan.resid)
plt.axhline(0,color='red')
plt.xlabel('urutan')
plt.ylabel('resedual')
# plt.xlim([1,31])
asm_homosk = sns.lineplot(sizes=([-5,5],[0,0]),color='red')
asm_homosk = plt.title('Residuals vs Prediction')

# %%
from sklearn.metrics import r2_score
print('accurancy:{:.3f}'.format(r2_score(table_enam.produk_terjual,model_data_iklan.predict(feature))))
# Out:
# accurancy:0.932

# %% [markdown]
# <div>
#     <h1 align="center"> Bab V <br> Regresi Linier Berganda</h1>
#     <p>
#     Regresi linear berganda merupakan model regresi yang melibatkan lebih dari satu variabel independen. Analisis regresi linear berganda dilakukan untuk mengetahui arah dan seberapa besar pengaruh variabel independen terhadap variabel dependen
#     </p>
# </div>

# %% [markdown]
# <div>
#     <ul>
#         <li><h3>Studi Kasus Linear Berganda</h3></li>
#     </ul>
# </div>

# %%
data_lulus=pd.read_csv('Statistika Regresi Berganda.csv')
data_lulus.columns=data_lulus.columns.str.lower()
data_lulus.columns=data_lulus.columns.str.replace(' ','_')
data_lulus.head()
# Out:
#     iq   ipk  tahun_lulus_di_universitas
# 0  108  3.12                         5.0
# 1  129  3.65                         3.5
# 2  130  3.52                         3.5
# 3  135  3.82                         3.5
# 4  110  3.25                         4.5

# %%
fig,ax=plt.subplots(1,2,figsize=[20,10])
sns.scatterplot(data=data_lulus,x='iq',y='tahun_lulus_di_universitas',ax=ax[0])
ax[0].set_title('iq vs tahun_lulus_di_universitas')
sns.scatterplot(data=data_lulus,x='ipk',y='tahun_lulus_di_universitas',ax=ax[1])
ax[1].set_title('ipk vs tahun_lulus_di_universitas')
# Out:
# Text(0.5, 1.0, 'ipk vs tahun_lulus_di_universitas')

# %% [markdown]
# ## make visualization dependens with Q-Q Plots

# %%
qqplot(data_lulus.tahun_lulus_di_universitas,line='s')
plt.show()

# %% [markdown]
# data nya tidak beraturan

# %%
feature=data_lulus.drop("tahun_lulus_di_universitas",axis=1).values
target=data_lulus.tahun_lulus_di_universitas.values.reshape(-1,1)
feature=sm.add_constant(feature)
model=sm.OLS(target,feature,missing='drop').fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.846
# Method:                 Least Squares   F-statistic:                     80.41
# Date:                Sun, 27 Nov 2022   Prob (F-statistic):           4.24e-12
# Time:                        19:28:52   Log-Likelihood:                 3.2075
# No. Observations:                  30   AIC:                           -0.4149
# Df Residuals:                      27   BIC:                             3.789
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.5132      0.511     20.569      0.000       9.464      11.562
# ...

# %% [markdown]
# hasilnya b0=10.5132 b1= -0.0262 b2=-0.9480

# %%
nilai_prediksi=model.predict(feature)
print('nilai prediksi pada studi kasus ini:\n',nilai_prediksi)
# Out:
# nilai prediksi pada studi kasus ini:
#  [4.72190466 3.66849479 3.76549993 3.34991461 4.54619042 4.81009388
#  4.74593705 4.14956533 4.10436873 4.03293577 3.53797715 3.54745726
#  4.52215803 4.44852109 4.46748132 3.40238735 3.33823052 3.37901916
#  3.25798163 4.81670583 4.56074269 4.51047394 4.47475745 3.20550889
#  3.86229368 4.18307784 4.19255795 3.75734821 3.75734821 4.88306664]

# %%
nilai_resedu=model.resid
print('nilai prediksi pada studi kasus ini:\n',nilai_resedu)
# Out:
# nilai prediksi pada studi kasus ini:
#  [ 0.27809534 -0.16849479 -0.26549993  0.15008539 -0.04619042  0.18990612
#   0.25406295 -0.14956533 -0.10436873 -0.03293577 -0.03797715 -0.04745726
#  -0.02215803 -0.44852109 -0.46748132  0.09761265  0.16176948  0.12098084
#   0.24201837  0.18329417  0.43925731 -0.01047394  0.02524255  0.29449111
#   0.13770632 -0.18307784 -0.19255795 -0.25734821 -0.25734821  0.11693336]

# %% [markdown]
# ### check penyerbaran data

# %%
sns.distplot(model.resid)
plt.title('pesebaran data setelah OLS')
# Out:
# /tmp/ipykernel_9474/2191032785.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(model.resid)
# Text(0.5, 1.0, 'pesebaran data setelah OLS')

# %%
qqplot(model.resid,line='s')
plt.title('Q-Q plot Visualization')
plt.show()

# %%
# uji nilai t
stats,t_value=shapiro(model.resid)
if t_value > .05:
    print('tolak H0')
    print('model bagus')

else:
    print('Gagal Tolak H0')
    print('model kurang bagus')
print(t_value)
# Out:
# tolak H0
# model bagus
# 0.7599719166755676

# %%
asm_homosk=plt.scatter(x=target,y=model.resid)
plt.title("Predict VS Residual")
plt.axhline(0,color='r')
plt.xlabel('prediksi')
plt.ylabel('residual')
# Out:
# Text(0, 0.5, 'residual')

# %% [markdown]
# # Pengujian Jeque

# %%
from statsmodels.compat import lzip
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
name=['Jarque-Bera',"Chi^2 two-tail prob",'skew','Kurtosis']
test=sms.jarque_bera(model.resid)
lzip(name,test)
# Out:
# [('Jarque-Bera', 0.6137718639092382),
#  ('Chi^2 two-tail prob', 0.73573451991953),
#  ('skew', -0.2533149753734306),
#  ('Kurtosis', 2.5159095289787006)]

# %% [markdown]
# studi Kasus

# %%
data_pasca_sarjana=pd.read_csv('Data Peluang di Terima Pasca.csv')
data_pasca_sarjana=data_pasca_sarjana.drop(columns=['Negara ke-'],axis=1)
data_pasca_sarjana.columns=data_pasca_sarjana.columns.str.lower()
data_pasca_sarjana.columns=data_pasca_sarjana.columns.str.replace(' ','_')
data_pasca_sarjana.head()
# Out:
#    toefl_ibt  nilai_ujian  peluang_di_terima
# 0        118          337               0.92
# 1        107          324               0.76
# 2        104          316               0.72
# 3        110          322               0.80
# 4        103          314               0.65

# %% [markdown]
# melihat pesebaran data dengan displot dan Q-Q Plot

# %%
qqplot(data_pasca_sarjana,line='s')
plt.title('Persebaran data Q-Q Plot')
plt.show()

# %%
plt.title('Pesebaran data sebelum di OLS')
sns.distplot(data_pasca_sarjana)
# Out:
# /tmp/ipykernel_9474/305599318.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_pasca_sarjana)
# <AxesSubplot: title={'center': 'Pesebaran data sebelum di OLS'}, ylabel='Density'>

# %% [markdown]
# mari kita melihat hubungan antara data independent dan variabel dependent

# %%
fig,ax=plt.subplots(1,2,figsize=[20,10])
fig.suptitle('Variabel Bebas Vs Variabel Tetap')
ax[0].set_title('toefl_ibt VS peluang_di_terima'.title())
sns.regplot(data=data_pasca_sarjana,x='toefl_ibt',y='peluang_di_terima',ax=ax[0],line_kws={'color':'r'})
ax[1].set_title('nilai_ujian VS peluang_di_terima'.title())
sns.regplot(data=data_pasca_sarjana,x='nilai_ujian',y='peluang_di_terima',ax=ax[1],line_kws={'color':'g'})
# Out:
# <AxesSubplot: title={'center': 'Nilai_Ujian Vs Peluang_Di_Terima'}, xlabel='nilai_ujian', ylabel='peluang_di_terima'>

# %% [markdown]
# hubungan data bebas antara akurab

# %%
sns.heatmap(data_pasca_sarjana.drop('peluang_di_terima',axis=1).corr(),vmax=1,vmin=-1,annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# membangun model

# %%
target=data_pasca_sarjana.peluang_di_terima.values.reshape(-1,1)
feature=data_pasca_sarjana.drop('peluang_di_terima',axis=1).values
feature=sm.add_constant(feature)
model_data=sm.OLS(target,feature,missing='drop').fit()
model_data.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     86.84
# Date:                Sun, 27 Nov 2022   Prob (F-statistic):           1.06e-14
# Time:                        19:28:55   Log-Likelihood:                 55.811
# No. Observations:                  40   AIC:                            -105.6
# Df Residuals:                      37   BIC:                            -100.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.2435      0.263     -8.527      0.000      -2.777      -1.710
# ...

# %% [markdown]
# penyebaran data

# %%
qqplot(model_data.resid,line='s')
plt.show()

# %%
sns.distplot(model_data.resid)
# Out:
# /tmp/ipykernel_9474/1447590991.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(model_data.resid)
# <AxesSubplot: ylabel='Density'>

# %%
_,p_value=shapiro(model_data.resid)
if p_value > .05:
    print('tolak H0')
    print('Model Bisa digunakan')
else:
    print('Gagal tolak H0')
    print('Model Bisa tidak digunakan')
print('P-Value:',p_value)
# Out:
# tolak H0
# Model Bisa digunakan
# P-Value: 0.7806366682052612

# %%
# AutoKorelasi
print('nilai korelasi:',sm.stats.stattools.durbin_watson(model_data.resid))
# Out:
# nilai korelasi: 1.7490940832969843

# %%
# homoskedastitas
homo_ask=plt.scatter(target,model_data.resid)
plt.xlabel('predicted')
plt.ylabel('residual')
plt.title('Predicted VS Residual')
plt.axhline(0,color='r')

# %%
data_pasca_sarjana.columns
# Out:
# Index(['toefl_ibt', 'nilai_ujian', 'peluang_di_terima'], dtype='object')

# %%
df_predict=pd.DataFrame({'score_ibt':data_pasca_sarjana.toefl_ibt,'nilai_ujian':data_pasca_sarjana.nilai_ujian})
df_predict['actual']=data_pasca_sarjana.peluang_di_terima
df_predict['prediksi']=model_data.predict(feature)

# %%
from sklearn.metrics import mean_squared_error,r2_score

print('acurancy:',r2_score(df_predict['actual'],df_predict['prediksi']))
print('MSE:',mean_squared_error(df_predict['actual'],df_predict['prediksi']))
# Out:
# acurancy: 0.8243749306624185
# MSE: 0.00359415606742677

# %%
from statsmodels.compat import lzip
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
name=['Jarque-Bera',"Chi^2 two-tail prob",'skew','Kurtosis']
test=sms.jarque_bera(model_data.resid)
lzip(name,test)
# Out:
# [('Jarque-Bera', 0.02989096955742756),
#  ('Chi^2 two-tail prob', 0.9851656446623002),
#  ('skew', 0.06591962564782584),
#  ('Kurtosis', 3.0235158149392816)]
